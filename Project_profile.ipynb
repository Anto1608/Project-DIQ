# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/Comune-di-Milano-Esercizi-di-vicinato-in-sede-fissa.csv',sep=';',encoding='unicode_escape')
data
# Out:
#                                     Settore Merceologico        Insegna  \
# 0                                                    NaN            NaN
# 1                                                    NaN            NaN
# 2                                                    NaN            NaN
# 3                                                    NaN            NaN
# 4                                                    NaN            NaN
# ...                                                  ...            ...
# 24131              Tabella speciale Monopolio;Alimentare            NaN
# 24132  Tabella speciale Monopolio;Alimentare;Non Alim...           i.p.
# 24133          tabella speciale monopolio;non alimentare  tabacchi noli
# 24134          Tabella speciale Monopolio;Non Alimentare            NaN
# 24135          Tabella speciale Monopolio;Non Alimentare            NaN
#
#                                               Ubicazione Tipo via  \
# ...

# %%
import sys
# !{sys.executable} -m pip install -U ydata-profiling[notebook]
# !pip install jupyter-contrib-nbextensions
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.1/686.1 kB 24.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 11.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.6/390.6 kB 32.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 87.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 kB 13.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 95.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 69.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.6/383.6 kB 32.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.5/133.5 kB 13.0 MB/s eta 0:00:00
# ...

# %%
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
# Paths used for configuration of notebook:
#     	/root/.jupyter/nbconfig/notebook.json
# Paths used for configuration of notebook:
#
#       - Validating: OK
# Paths used for configuration of notebook:
#     	/root/.jupyter/nbconfig/notebook.json

# %%
from ydata_profiling import ProfileReport
import pandas as pd
import json

# %%
#create a profile report
PROFILE = ProfileReport(data, title="Profiling Report")
PROFILE
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
#create a profile report in json
PROFILE.to_file("proj_REPORT.json")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
file = open("proj_REPORT.json")
JFILE = json.load(file)

# %%
JFILE
# Out:
# Output hidden; open in https://colab.research.google.com to view.
